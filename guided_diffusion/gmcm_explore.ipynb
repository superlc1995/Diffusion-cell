# %%
import numpy as np

comp_10 = np.load('/home/lchen/cell_dectection/CrowdCounting-P2PNet/part_A/train_data/gmcm_den/IMG_3/BIC_10_199.6703.npy')
comp_2 = np.load('/home/lchen/cell_dectection/CrowdCounting-P2PNet/part_A/train_data/gmcm_den/IMG_3/BIC_2_-21.360062.npy')
comp_1 = np.load('/home/lchen/cell_dectection/CrowdCounting-P2PNet/part_A/train_data/gmcm_den/IMG_3/BIC_1_28.008274.npy')

# %%
comp_10 = np.load('/home/lchen/cell_dectection/CrowdCounting-P2PNet/part_A/train_data/gmcm_den/IMG_16/BIC_10_100.35512.npy')
comp_2 = np.load('/home/lchen/cell_dectection/CrowdCounting-P2PNet/part_A/train_data/gmcm_den/IMG_16/BIC_2_-54.63669.npy')
comp_1 = np.load('/home/lchen/cell_dectection/CrowdCounting-P2PNet/part_A/train_data/gmcm_den/IMG_16/BIC_1_15.508741.npy')

# %%
print(np.sum(comp_10))
print(np.sum(comp_2))
print(np.sum(comp_1))
# Out:
# 12542.563
# 23330.492
# 11384.861

# %%
np.sum(comp_2)
# Out:
# 23330.492

# %%
import matplotlib.pyplot as plt

plt.imshow(comp_10)

# %%
np.sum(comp_10)
# Out:
# 12518.299

# %%
np.sum(comp_2)
# Out:
# 12957.059

# %%
np.sum(comp_1)
# Out:
# 9157.718
